# %%
import os
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy import oauth2
import random
from functools import reduce
# Out:
# C:\Users\Himansh\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Inserting Spotify username & credentials: From developers.spotify
cid = '**************************'
secret = '*********************************'
redirect_uri='http://localhost:9000/callback'
username = '**************'

# %%
# Once the Authorisation is complete, we just need to `sp` to call the APIs
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
results = sp.current_user_top_tracks(limit=50, offset=0,time_range='medium_term')
results
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yvcSjfu4PC0CYQyLy4wSq'},
#       'href': 'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq',
#       'id': '4yvcSjfu4PC0CYQyLy4wSq',
#       'name': 'Glass Animals',
#       'type': 'artist',
#       'uri': 'spotify:artist:4yvcSjfu4PC0CYQyLy4wSq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0KTj6k94XZh0c6IEMfxeWV'},
#     'href': 'https://api.spotify.com/v1/albums/0KTj6k94XZh0c6IEMfxeWV',
#     'id': '0KTj6k94XZh0c6IEMfxeWV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739e495fb707973f3390850eea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029e495fb707973f3390850eea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519e495fb707973f3390850eea',
#       'width': 64}],
#     'name': 'Dreamland (+ Bonus Levels)',
#     'release_date': '2020-08-06',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:0KTj6k94XZh0c6IEMfxeWV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yvcSjfu4PC0CYQyLy4wSq'},
#      'href': 'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq',
#      'id': '4yvcSjfu4PC0CYQyLy4wSq',
#      'name': 'Glass Animals',
#      'type': 'artist',
#      'uri': 'spotify:artist:4yvcSjfu4PC0CYQyLy4wSq'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 234372,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM72000802'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3NAGZe9GWtE8Nvfj6huEzE'},
#    'href': 'https://api.spotify.com/v1/tracks/3NAGZe9GWtE8Nvfj6huEzE',
#    'id': '3NAGZe9GWtE8Nvfj6huEzE',
#    'is_local': False,
#    'name': 'Your Love (Déjà Vu)',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d0c391d15c0416cfc2f8a191d279e86f020b4700?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:3NAGZe9GWtE8Nvfj6huEzE'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nvdwVbj7NT1WL9P8JowLD'},
#       'href': 'https://api.spotify.com/v1/artists/0nvdwVbj7NT1WL9P8JowLD',
#       'id': '0nvdwVbj7NT1WL9P8JowLD',
#       'name': 'blackwave.',
#       'type': 'artist',
#       'uri': 'spotify:artist:0nvdwVbj7NT1WL9P8JowLD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/24aBKIQMXzdMYZkWSGFLTK'},
#     'href': 'https://api.spotify.com/v1/albums/24aBKIQMXzdMYZkWSGFLTK',
#     'id': '24aBKIQMXzdMYZkWSGFLTK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737454ee329a17695a8e893060',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027454ee329a17695a8e893060',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517454ee329a17695a8e893060',
#       'width': 64}],
#     'name': 'Elusive',
#     'release_date': '2017-10-09',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:24aBKIQMXzdMYZkWSGFLTK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nvdwVbj7NT1WL9P8JowLD'},
#      'href': 'https://api.spotify.com/v1/artists/0nvdwVbj7NT1WL9P8JowLD',
#      'id': '0nvdwVbj7NT1WL9P8JowLD',
#      'name': 'blackwave.',
#      'type': 'artist',
#      'uri': 'spotify:artist:0nvdwVbj7NT1WL9P8JowLD'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2HkyxGmwcNwdXWOawm0J8c'},
#      'href': 'https://api.spotify.com/v1/artists/2HkyxGmwcNwdXWOawm0J8c',
#      'id': '2HkyxGmwcNwdXWOawm0J8c',
#      'name': 'David Ngyah',
#      'type': 'artist',
#      'uri': 'spotify:artist:2HkyxGmwcNwdXWOawm0J8c'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 222200,
#    'explicit': False,
#    'external_ids': {'isrc': 'BEFM11700009'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4mbOTHs6heygME9uDHg0mf'},
#    'href': 'https://api.spotify.com/v1/tracks/4mbOTHs6heygME9uDHg0mf',
#    'id': '4mbOTHs6heygME9uDHg0mf',
#    'is_local': False,
#    'name': 'Elusive',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/992ef7cc4fd786a6c8faa20a3d346207b94dfb20?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4mbOTHs6heygME9uDHg0mf'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eU0jV2eEZ8XTM7EmlguK6'},
#       'href': 'https://api.spotify.com/v1/artists/6eU0jV2eEZ8XTM7EmlguK6',
#       'id': '6eU0jV2eEZ8XTM7EmlguK6',
#       'name': 'Black Pumas',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eU0jV2eEZ8XTM7EmlguK6'}],
#     'available_markets': ['AD',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'CH',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HU',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'NL',
#      'NO',
#      'NZ',
#      'PL',
#      'PT',
#      'RO',
#      'SE',
#      'SK',
#      'TR'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3g8HE8pB8nq6DbHf71I2Wa'},
#     'href': 'https://api.spotify.com/v1/albums/3g8HE8pB8nq6DbHf71I2Wa',
#     'id': '3g8HE8pB8nq6DbHf71I2Wa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733b14d2d2c0bc40021dcd9a3b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023b14d2d2c0bc40021dcd9a3b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513b14d2d2c0bc40021dcd9a3b',
#       'width': 64}],
#     'name': 'Black Pumas',
#     'release_date': '2019-06-21',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3g8HE8pB8nq6DbHf71I2Wa'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eU0jV2eEZ8XTM7EmlguK6'},
#      'href': 'https://api.spotify.com/v1/artists/6eU0jV2eEZ8XTM7EmlguK6',
#      'id': '6eU0jV2eEZ8XTM7EmlguK6',
#      'name': 'Black Pumas',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eU0jV2eEZ8XTM7EmlguK6'}],
#    'available_markets': ['AD',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'CH',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'HU',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'NL',
#     'NO',
#     'NZ',
#     'PL',
#     'PT',
#     'RO',
#     'SE',
#     'SK',
#     'TR'],
#    'disc_number': 1,
#    'duration_ms': 246586,
#    'explicit': False,
#    'external_ids': {'isrc': 'USATO1900023'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6J3HNhDBIwEX11bX8hzx5u'},
#    'href': 'https://api.spotify.com/v1/tracks/6J3HNhDBIwEX11bX8hzx5u',
#    'id': '6J3HNhDBIwEX11bX8hzx5u',
#    'is_local': False,
#    'name': 'Colors',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7bc7f3d592ab101d2d208fb4debb789a85b45fb9?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6J3HNhDBIwEX11bX8hzx5u'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AcUPzkVWo81vumdzeLLRN'},
#       'href': 'https://api.spotify.com/v1/artists/2AcUPzkVWo81vumdzeLLRN',
#       'id': '2AcUPzkVWo81vumdzeLLRN',
#       'name': 'Rhye',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AcUPzkVWo81vumdzeLLRN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1AvkRISSdzC7cq7eLoS5w1'},
#     'href': 'https://api.spotify.com/v1/albums/1AvkRISSdzC7cq7eLoS5w1',
#     'id': '1AvkRISSdzC7cq7eLoS5w1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d266d98f5f9a0ba1fd1aeac1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d266d98f5f9a0ba1fd1aeac1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d266d98f5f9a0ba1fd1aeac1',
#       'width': 64}],
#     'name': 'Blood Remixed',
#     'release_date': '2018-11-16',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1AvkRISSdzC7cq7eLoS5w1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AcUPzkVWo81vumdzeLLRN'},
#      'href': 'https://api.spotify.com/v1/artists/2AcUPzkVWo81vumdzeLLRN',
#      'id': '2AcUPzkVWo81vumdzeLLRN',
#      'name': 'Rhye',
#      'type': 'artist',
#      'uri': 'spotify:artist:2AcUPzkVWo81vumdzeLLRN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5szdY7KaSi7epwyffrbV8c'},
#      'href': 'https://api.spotify.com/v1/artists/5szdY7KaSi7epwyffrbV8c',
#      'id': '5szdY7KaSi7epwyffrbV8c',
#      'name': 'Poolside',
#      'type': 'artist',
#      'uri': 'spotify:artist:5szdY7KaSi7epwyffrbV8c'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 310133,
#    'explicit': False,
#    'external_ids': {'isrc': 'USC4R1802509'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1hgX0ZmmP7IRRjUFCIBrnQ'},
#    'href': 'https://api.spotify.com/v1/tracks/1hgX0ZmmP7IRRjUFCIBrnQ',
#    'id': '1hgX0ZmmP7IRRjUFCIBrnQ',
#    'is_local': False,
#    'name': 'Feel Your Weight - Poolside Remix',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/930f0acb97252c8a23e22a59448b219ae38c55bf?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1hgX0ZmmP7IRRjUFCIBrnQ'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bxVbtf4t5k1QPmy0XDvgv'},
#       'href': 'https://api.spotify.com/v1/artists/5bxVbtf4t5k1QPmy0XDvgv',
#       'id': '5bxVbtf4t5k1QPmy0XDvgv',
#       'name': 'Shamoon Ismail',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bxVbtf4t5k1QPmy0XDvgv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/59Dfy0P1tm0IgSCU1luKHu'},
#     'href': 'https://api.spotify.com/v1/albums/59Dfy0P1tm0IgSCU1luKHu',
#     'id': '59Dfy0P1tm0IgSCU1luKHu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d02b9826354eb7814747fda1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d02b9826354eb7814747fda1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d02b9826354eb7814747fda1',
#       'width': 64}],
#     'name': 'Brown Sugar',
#     'release_date': '2019-08-30',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:59Dfy0P1tm0IgSCU1luKHu'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bxVbtf4t5k1QPmy0XDvgv'},
#      'href': 'https://api.spotify.com/v1/artists/5bxVbtf4t5k1QPmy0XDvgv',
#      'id': '5bxVbtf4t5k1QPmy0XDvgv',
#      'name': 'Shamoon Ismail',
#      'type': 'artist',
#      'uri': 'spotify:artist:5bxVbtf4t5k1QPmy0XDvgv'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 177413,
#    'explicit': True,
#    'external_ids': {'isrc': 'ushm81994410'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ibHHhuRj8od0hgKx0xHRb'},
#    'href': 'https://api.spotify.com/v1/tracks/3ibHHhuRj8od0hgKx0xHRb',
#    'id': '3ibHHhuRj8od0hgKx0xHRb',
#    'is_local': False,
#    'name': 'Late Night',
#    'popularity': 39,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1c728b8c5971bc9be2cf012e4b0b9c4726fa4cf1?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3ibHHhuRj8od0hgKx0xHRb'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nxWCVXbOlEVRexSbLsTer'},
#       'href': 'https://api.spotify.com/v1/artists/6nxWCVXbOlEVRexSbLsTer',
#       'id': '6nxWCVXbOlEVRexSbLsTer',
#       'name': 'Flume',
#       'type': 'artist',
#       'uri': 'spotify:artist:6nxWCVXbOlEVRexSbLsTer'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6O4EGCCb6DoIiR6B1QCQgp'},
#       'href': 'https://api.spotify.com/v1/artists/6O4EGCCb6DoIiR6B1QCQgp',
#       'id': '6O4EGCCb6DoIiR6B1QCQgp',
#       'name': 'Toro y Moi',
#       'type': 'artist',
#       'uri': 'spotify:artist:6O4EGCCb6DoIiR6B1QCQgp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3QgFzksD4J43TnGIJOOrRV'},
#     'href': 'https://api.spotify.com/v1/albums/3QgFzksD4J43TnGIJOOrRV',
#     'id': '3QgFzksD4J43TnGIJOOrRV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a8d74e789b99484e0e169001',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a8d74e789b99484e0e169001',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a8d74e789b99484e0e169001',
#       'width': 64}],
#     'name': 'The Difference',
#     'release_date': '2020-03-11',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3QgFzksD4J43TnGIJOOrRV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nxWCVXbOlEVRexSbLsTer'},
#      'href': 'https://api.spotify.com/v1/artists/6nxWCVXbOlEVRexSbLsTer',
#      'id': '6nxWCVXbOlEVRexSbLsTer',
#      'name': 'Flume',
#      'type': 'artist',
#      'uri': 'spotify:artist:6nxWCVXbOlEVRexSbLsTer'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6O4EGCCb6DoIiR6B1QCQgp'},
#      'href': 'https://api.spotify.com/v1/artists/6O4EGCCb6DoIiR6B1QCQgp',
#      'id': '6O4EGCCb6DoIiR6B1QCQgp',
#      'name': 'Toro y Moi',
#      'type': 'artist',
#      'uri': 'spotify:artist:6O4EGCCb6DoIiR6B1QCQgp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 139662,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUFF02000008'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4nlvKIIetOWGIMyhjQXgOZ'},
#    'href': 'https://api.spotify.com/v1/tracks/4nlvKIIetOWGIMyhjQXgOZ',
#    'id': '4nlvKIIetOWGIMyhjQXgOZ',
#    'is_local': False,
#    'name': 'The Difference',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9c4225af3c01d6de5dc9adf61fc07aa3ff38de0c?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4nlvKIIetOWGIMyhjQXgOZ'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0QGDb8TBWIT06W4BoyAggg'},
#       'href': 'https://api.spotify.com/v1/artists/0QGDb8TBWIT06W4BoyAggg',
#       'id': '0QGDb8TBWIT06W4BoyAggg',
#       'name': 'Finding Hope',
#       'type': 'artist',
#       'uri': 'spotify:artist:0QGDb8TBWIT06W4BoyAggg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3xL3IZe5y1MdkYsoC1y6nW'},
#     'href': 'https://api.spotify.com/v1/albums/3xL3IZe5y1MdkYsoC1y6nW',
#     'id': '3xL3IZe5y1MdkYsoC1y6nW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737f9ad7a86a5a7bdc411d6f07',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027f9ad7a86a5a7bdc411d6f07',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517f9ad7a86a5a7bdc411d6f07',
#       'width': 64}],
#     'name': 'Apollo 19',
#     'release_date': '2019-12-02',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:3xL3IZe5y1MdkYsoC1y6nW'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0QGDb8TBWIT06W4BoyAggg'},
#      'href': 'https://api.spotify.com/v1/artists/0QGDb8TBWIT06W4BoyAggg',
#      'id': '0QGDb8TBWIT06W4BoyAggg',
#      'name': 'Finding Hope',
#      'type': 'artist',
#      'uri': 'spotify:artist:0QGDb8TBWIT06W4BoyAggg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 164000,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZHNA1915495'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1oAMeG9XWoIHKG2nTAgTku'},
#    'href': 'https://api.spotify.com/v1/tracks/1oAMeG9XWoIHKG2nTAgTku',
#    'id': '1oAMeG9XWoIHKG2nTAgTku',
#    'is_local': False,
#    'name': '25 Hours',
#    'popularity': 37,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ec8e00fb794402a8c964481465033633b49e817f?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1oAMeG9XWoIHKG2nTAgTku'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25tMQOrIU4LlUo6Sv8v5SE'},
#       'href': 'https://api.spotify.com/v1/artists/25tMQOrIU4LlUo6Sv8v5SE',
#       'id': '25tMQOrIU4LlUo6Sv8v5SE',
#       'name': 'Gavin James',
#       'type': 'artist',
#       'uri': 'spotify:artist:25tMQOrIU4LlUo6Sv8v5SE'}],
#     'available_markets': ['AE',
#      'AR',
#      'AU',
#      'BH',
#      'BO',
#      'BR',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'DZ',
#      'EC',
#      'EG',
#      'FR',
#      'GB',
#      'HK',
#      'HN',
#      'ID',
#      'IN',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'MA',
#      'MY',
#      'NI',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PS',
#      'PY',
#      'QA',
#      'SA',
#      'SG',
#      'SV',
#      'TH',
#      'TN',
#      'TW',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1j1gfzcvAoQb2IJenqVQ3v'},
#     'href': 'https://api.spotify.com/v1/albums/1j1gfzcvAoQb2IJenqVQ3v',
#     'id': '1j1gfzcvAoQb2IJenqVQ3v',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735909a32eee61a7be2f5ce6ff',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025909a32eee61a7be2f5ce6ff',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515909a32eee61a7be2f5ce6ff',
#       'width': 64}],
#     'name': 'Only Ticket Home',
#     'release_date': '2018-10-26',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1j1gfzcvAoQb2IJenqVQ3v'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25tMQOrIU4LlUo6Sv8v5SE'},
#      'href': 'https://api.spotify.com/v1/artists/25tMQOrIU4LlUo6Sv8v5SE',
#      'id': '25tMQOrIU4LlUo6Sv8v5SE',
#      'name': 'Gavin James',
#      'type': 'artist',
#      'uri': 'spotify:artist:25tMQOrIU4LlUo6Sv8v5SE'}],
#    'available_markets': ['AE',
#     'AR',
#     'AU',
#     'BH',
#     'BO',
#     'BR',
#     'CL',
#     'CO',
#     'CR',
#     'DO',
#     'DZ',
#     'EC',
#     'EG',
#     'FR',
#     'GB',
#     'HK',
#     'HN',
#     'ID',
#     'IN',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'MA',
#     'MY',
#     'NI',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PS',
#     'PY',
#     'QA',
#     'SA',
#     'SG',
#     'SV',
#     'TH',
#     'TN',
#     'TW',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 247842,
#    'explicit': False,
#    'external_ids': {'isrc': 'GB45A1800988'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/79wvYwZgtfcnCwBI8XIep8'},
#    'href': 'https://api.spotify.com/v1/tracks/79wvYwZgtfcnCwBI8XIep8',
#    'id': '79wvYwZgtfcnCwBI8XIep8',
#    'is_local': False,
#    'name': 'Always',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c2569cbafb3d07cf6409569ea855bda4cfd7d6e4?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:79wvYwZgtfcnCwBI8XIep8'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nUF7iT0e6D5xEl743Jfu3'},
#       'href': 'https://api.spotify.com/v1/artists/0nUF7iT0e6D5xEl743Jfu3',
#       'id': '0nUF7iT0e6D5xEl743Jfu3',
#       'name': 'Icarus',
#       'type': 'artist',
#       'uri': 'spotify:artist:0nUF7iT0e6D5xEl743Jfu3'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/01WcFlWlj9ie3YTNSKr3OP'},
#     'href': 'https://api.spotify.com/v1/albums/01WcFlWlj9ie3YTNSKr3OP',
#     'id': '01WcFlWlj9ie3YTNSKr3OP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27347c42bab8cbab77466bb8ea4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0247c42bab8cbab77466bb8ea4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485147c42bab8cbab77466bb8ea4',
#       'width': 64}],
#     'name': 'This Must Be The Place',
#     'release_date': '2019-02-07',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:01WcFlWlj9ie3YTNSKr3OP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0nUF7iT0e6D5xEl743Jfu3'},
#      'href': 'https://api.spotify.com/v1/artists/0nUF7iT0e6D5xEl743Jfu3',
#      'id': '0nUF7iT0e6D5xEl743Jfu3',
#      'name': 'Icarus',
#      'type': 'artist',
#      'uri': 'spotify:artist:0nUF7iT0e6D5xEl743Jfu3'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 255520,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE1900112'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0EudqIdrpZjHZ1pnSuBKgA'},
#    'href': 'https://api.spotify.com/v1/tracks/0EudqIdrpZjHZ1pnSuBKgA',
#    'id': '0EudqIdrpZjHZ1pnSuBKgA',
#    'is_local': False,
#    'name': 'Sirens',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c6586b3bcca23dc022286938f24f275c3e3209fc?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0EudqIdrpZjHZ1pnSuBKgA'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IwM0dNvhWqqtsTyulxe2K'},
#       'href': 'https://api.spotify.com/v1/artists/4IwM0dNvhWqqtsTyulxe2K',
#       'id': '4IwM0dNvhWqqtsTyulxe2K',
#       'name': '53 Thieves',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IwM0dNvhWqqtsTyulxe2K'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4OVHuaHyH9KpFwgbJTdSS1'},
#     'href': 'https://api.spotify.com/v1/albums/4OVHuaHyH9KpFwgbJTdSS1',
#     'id': '4OVHuaHyH9KpFwgbJTdSS1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27327476d9d6e32d5db0ec1e56b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0227476d9d6e32d5db0ec1e56b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485127476d9d6e32d5db0ec1e56b',
#       'width': 64}],
#     'name': "dreamin'",
#     'release_date': '2020-02-07',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:4OVHuaHyH9KpFwgbJTdSS1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IwM0dNvhWqqtsTyulxe2K'},
#      'href': 'https://api.spotify.com/v1/artists/4IwM0dNvhWqqtsTyulxe2K',
#      'id': '4IwM0dNvhWqqtsTyulxe2K',
#      'name': '53 Thieves',
#      'type': 'artist',
#      'uri': 'spotify:artist:4IwM0dNvhWqqtsTyulxe2K'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 207705,
#    'explicit': True,
#    'external_ids': {'isrc': 'DEVF12000602'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4PlzJVdaRYC9Fg2AqlOxer'},
#    'href': 'https://api.spotify.com/v1/tracks/4PlzJVdaRYC9Fg2AqlOxer',
#    'id': '4PlzJVdaRYC9Fg2AqlOxer',
#    'is_local': False,
#    'name': "dreamin'",
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/afa91557e381e619cb4ba056c357c04457a5df74?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4PlzJVdaRYC9Fg2AqlOxer'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nxWCVXbOlEVRexSbLsTer'},
#       'href': 'https://api.spotify.com/v1/artists/6nxWCVXbOlEVRexSbLsTer',
#       'id': '6nxWCVXbOlEVRexSbLsTer',
#       'name': 'Flume',
#       'type': 'artist',
#       'uri': 'spotify:artist:6nxWCVXbOlEVRexSbLsTer'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ujrA1eZLDHR7yQ6FZa2qA'},
#       'href': 'https://api.spotify.com/v1/artists/5ujrA1eZLDHR7yQ6FZa2qA',
#       'id': '5ujrA1eZLDHR7yQ6FZa2qA',
#       'name': 'Vera Blue',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ujrA1eZLDHR7yQ6FZa2qA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4d2YOjyPDopVhOkksaALJj'},
#     'href': 'https://api.spotify.com/v1/albums/4d2YOjyPDopVhOkksaALJj',
#     'id': '4d2YOjyPDopVhOkksaALJj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273683d659e308221da35d3c0ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02683d659e308221da35d3c0ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851683d659e308221da35d3c0ca',
#       'width': 64}],
#     'name': 'Rushing Back',
#     'release_date': '2019-09-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4d2YOjyPDopVhOkksaALJj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nxWCVXbOlEVRexSbLsTer'},
#      'href': 'https://api.spotify.com/v1/artists/6nxWCVXbOlEVRexSbLsTer',
#      'id': '6nxWCVXbOlEVRexSbLsTer',
#      'name': 'Flume',
#      'type': 'artist',
#      'uri': 'spotify:artist:6nxWCVXbOlEVRexSbLsTer'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ujrA1eZLDHR7yQ6FZa2qA'},
#      'href': 'https://api.spotify.com/v1/artists/5ujrA1eZLDHR7yQ6FZa2qA',
#      'id': '5ujrA1eZLDHR7yQ6FZa2qA',
#      'name': 'Vera Blue',
#      'type': 'artist',
#      'uri': 'spotify:artist:5ujrA1eZLDHR7yQ6FZa2qA'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 231663,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUFF01900128'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2zoNNEAyPK2OGDfajardlY'},
#    'href': 'https://api.spotify.com/v1/tracks/2zoNNEAyPK2OGDfajardlY',
#    'id': '2zoNNEAyPK2OGDfajardlY',
#    'is_local': False,
#    'name': 'Rushing Back',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/373526a105a500ceab84e7e0f2b86bae612f63de?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2zoNNEAyPK2OGDfajardlY'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#       'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#       'id': '5NHm4TU5Twz7owibYxJfFU',
#       'name': 'King',
#       'type': 'artist',
#       'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2UWDKfS49B76u1cr0wZirC'},
#     'href': 'https://api.spotify.com/v1/albums/2UWDKfS49B76u1cr0wZirC',
#     'id': '2UWDKfS49B76u1cr0wZirC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d82ac1461ba2dee11e73e4d9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d82ac1461ba2dee11e73e4d9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d82ac1461ba2dee11e73e4d9',
#       'width': 64}],
#     'name': 'Tum Saath Rehnaa',
#     'release_date': '2019-12-14',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2UWDKfS49B76u1cr0wZirC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NHm4TU5Twz7owibYxJfFU'},
#      'href': 'https://api.spotify.com/v1/artists/5NHm4TU5Twz7owibYxJfFU',
#      'id': '5NHm4TU5Twz7owibYxJfFU',
#      'name': 'King',
#      'type': 'artist',
#      'uri': 'spotify:artist:5NHm4TU5Twz7owibYxJfFU'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 215536,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZK6P1921017'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Ft4Tj0l8kzfKBv8vGuR4t'},
#    'href': 'https://api.spotify.com/v1/tracks/4Ft4Tj0l8kzfKBv8vGuR4t',
#    'id': '4Ft4Tj0l8kzfKBv8vGuR4t',
#    'is_local': False,
#    'name': 'Tum Saath Rehnaa',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/00e759091d83a29ad028eca6b97203f0d188eb82?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4Ft4Tj0l8kzfKBv8vGuR4t'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ON0EY1YuVEJPwj17yYtwO'},
#     'href': 'https://api.spotify.com/v1/albums/5ON0EY1YuVEJPwj17yYtwO',
#     'id': '5ON0EY1YuVEJPwj17yYtwO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395998c6ca2c759356eee3c3b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295998c6ca2c759356eee3c3b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195998c6ca2c759356eee3c3b',
#       'width': 64}],
#     'name': 'To Let A Good Thing Die',
#     'release_date': '2020-06-05',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5ON0EY1YuVEJPwj17yYtwO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
# ...
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 144962,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM24S1916211'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6WpE1zKOrnVKNDUHzwsUJ7'},
#    'href': 'https://api.spotify.com/v1/tracks/6WpE1zKOrnVKNDUHzwsUJ7',
#    'id': '6WpE1zKOrnVKNDUHzwsUJ7',
#    'is_local': False,
#    'name': 'Left Side',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4ccd22aa7f303a4187a7522bd671f12fd6a199ce?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6WpE1zKOrnVKNDUHzwsUJ7'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3S4d3YRNGg2OhnNm3QvfhA'},
#       'href': 'https://api.spotify.com/v1/artists/3S4d3YRNGg2OhnNm3QvfhA',
#       'id': '3S4d3YRNGg2OhnNm3QvfhA',
#       'name': 'slenderbodies',
#       'type': 'artist',
#       'uri': 'spotify:artist:3S4d3YRNGg2OhnNm3QvfhA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4HC2G7sSf1JG3puEMHvQBb'},
#     'href': 'https://api.spotify.com/v1/albums/4HC2G7sSf1JG3puEMHvQBb',
#     'id': '4HC2G7sSf1JG3puEMHvQBb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273468b7751aa2ba5f2999aa70b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02468b7751aa2ba5f2999aa70b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851468b7751aa2ba5f2999aa70b',
#       'width': 64}],
#     'name': 'sotto voce',
#     'release_date': '2016-06-12',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:4HC2G7sSf1JG3puEMHvQBb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3S4d3YRNGg2OhnNm3QvfhA'},
#      'href': 'https://api.spotify.com/v1/artists/3S4d3YRNGg2OhnNm3QvfhA',
#      'id': '3S4d3YRNGg2OhnNm3QvfhA',
#      'name': 'slenderbodies',
#      'type': 'artist',
#      'uri': 'spotify:artist:3S4d3YRNGg2OhnNm3QvfhA'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 183157,
#    'explicit': False,
#    'external_ids': {'isrc': 'SEYOK1632441'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6k8Z9CtoRLk9mXarke5LHQ'},
#    'href': 'https://api.spotify.com/v1/tracks/6k8Z9CtoRLk9mXarke5LHQ',
#    'id': '6k8Z9CtoRLk9mXarke5LHQ',
#    'is_local': False,
#    'name': 'gray',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6ecbdc1e5850ee6eb632ccb94244e67d72f35a97?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6k8Z9CtoRLk9mXarke5LHQ'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#       'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#       'id': '0hEurMDQu99nJRq8pTxO14',
#       'name': 'John Mayer',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Xsprdt1q9rOzTic7b9zYM'},
#     'href': 'https://api.spotify.com/v1/albums/1Xsprdt1q9rOzTic7b9zYM',
#     'id': '1Xsprdt1q9rOzTic7b9zYM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737af5fdc5ef048a68db62b85f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027af5fdc5ef048a68db62b85f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517af5fdc5ef048a68db62b85f',
#       'width': 64}],
#     'name': 'Continuum',
#     'release_date': '2006-09-11',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1Xsprdt1q9rOzTic7b9zYM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hEurMDQu99nJRq8pTxO14'},
#      'href': 'https://api.spotify.com/v1/artists/0hEurMDQu99nJRq8pTxO14',
#      'id': '0hEurMDQu99nJRq8pTxO14',
#      'name': 'John Mayer',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hEurMDQu99nJRq8pTxO14'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 242000,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10603632'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2jdAk8ATWIL3dwT47XpRfu'},
#    'href': 'https://api.spotify.com/v1/tracks/2jdAk8ATWIL3dwT47XpRfu',
#    'id': '2jdAk8ATWIL3dwT47XpRfu',
#    'is_local': False,
#    'name': 'Slow Dancing in a Burning Room',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/43906dc15ec117192b9f2a83021c70d9c6f309c0?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:2jdAk8ATWIL3dwT47XpRfu'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TQj5BFPooTa08A7pk8AQ1'},
#       'href': 'https://api.spotify.com/v1/artists/6TQj5BFPooTa08A7pk8AQ1',
#       'id': '6TQj5BFPooTa08A7pk8AQ1',
#       'name': 'Kaskade',
#       'type': 'artist',
#       'uri': 'spotify:artist:6TQj5BFPooTa08A7pk8AQ1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1HBbdAD7XMGn8ePLKzH9Iq'},
#     'href': 'https://api.spotify.com/v1/albums/1HBbdAD7XMGn8ePLKzH9Iq',
#     'id': '1HBbdAD7XMGn8ePLKzH9Iq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27387a4384e128ac4bf8c797ea4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0287a4384e128ac4bf8c797ea4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485187a4384e128ac4bf8c797ea4',
#       'width': 64}],
#     'name': 'On Your Mind',
#     'release_date': '2018-12-07',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1HBbdAD7XMGn8ePLKzH9Iq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6TQj5BFPooTa08A7pk8AQ1'},
#      'href': 'https://api.spotify.com/v1/artists/6TQj5BFPooTa08A7pk8AQ1',
#      'id': '6TQj5BFPooTa08A7pk8AQ1',
#      'name': 'Kaskade',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TQj5BFPooTa08A7pk8AQ1'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 320280,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG11802826'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5IpIl6c14WCJhjlIl6poVD'},
#    'href': 'https://api.spotify.com/v1/tracks/5IpIl6c14WCJhjlIl6poVD',
#    'id': '5IpIl6c14WCJhjlIl6poVD',
#    'is_local': False,
#    'name': 'On Your Mind',
#    'popularity': 65,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d0113b179dca4d1be8b713c9b70e236fc118a8a6?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5IpIl6c14WCJhjlIl6poVD'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RP4pPHTXlQpDnO9LvR7Yt'},
#       'href': 'https://api.spotify.com/v1/artists/2RP4pPHTXlQpDnO9LvR7Yt',
#       'id': '2RP4pPHTXlQpDnO9LvR7Yt',
#       'name': 'Lianne La Havas',
#       'type': 'artist',
#       'uri': 'spotify:artist:2RP4pPHTXlQpDnO9LvR7Yt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1CqNrKEv2fhF7mudTXrydV'},
#     'href': 'https://api.spotify.com/v1/albums/1CqNrKEv2fhF7mudTXrydV',
#     'id': '1CqNrKEv2fhF7mudTXrydV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273389e657f84c49346d6bdc40d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02389e657f84c49346d6bdc40d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851389e657f84c49346d6bdc40d',
#       'width': 64}],
#     'name': 'Lianne La Havas',
#     'release_date': '2020-07-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:1CqNrKEv2fhF7mudTXrydV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RP4pPHTXlQpDnO9LvR7Yt'},
#      'href': 'https://api.spotify.com/v1/artists/2RP4pPHTXlQpDnO9LvR7Yt',
#      'id': '2RP4pPHTXlQpDnO9LvR7Yt',
#      'name': 'Lianne La Havas',
#      'type': 'artist',
#      'uri': 'spotify:artist:2RP4pPHTXlQpDnO9LvR7Yt'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 298720,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAHT2000176'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7kC97zPE0PxrcItXyGdk8P'},
#    'href': 'https://api.spotify.com/v1/tracks/7kC97zPE0PxrcItXyGdk8P',
#    'id': '7kC97zPE0PxrcItXyGdk8P',
#    'is_local': False,
#    'name': 'Paper Thin',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/21500cbeb51c3f9f814453287255ab32b2e8bf3a?cid=862e7c5758164556808ab4e6aab6f316',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7kC97zPE0PxrcItXyGdk8P'}],
#  'total': 50,
#  'limit': 50,
#  'offset': 0,
#  'previous': None,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?limit=50&offset=0',
#  'next': None}

# %%
# Convert it to Dataframe
track_name = []
track_id = []
artist = []
album = []
duration = []
popularity = []
for i, items in enumerate(results['items']):
        track_name.append(items['name'])
        track_id.append(items['id'])
        artist.append(items["artists"][0]["name"])
        duration.append(items["duration_ms"])
        album.append(items["album"]["name"])
        popularity.append(items["popularity"])

# Create the final df   
df_favourite = pd.DataFrame({ "track_name": track_name, 
                             "album": album, 
                             "track_id": track_id,
                             "artist": artist, 
                             "duration": duration, 
                             "popularity": popularity})

df_favourite
# Out:
#                                   track_name  \
# 0                        Your Love (Déjà Vu)
# 1                                    Elusive
# 2                                     Colors
# 3          Feel Your Weight - Poolside Remix
# 4                                 Late Night
# 5                             The Difference
# 6                                   25 Hours
# 7                                     Always
# 8                                     Sirens
# 9                                   dreamin'
# 10                              Rushing Back
# 11                          Tum Saath Rehnaa
# 12                  The Most Beautiful Thing
# 13                       You're Too Precious
# 14                                  with you
# 15                                 Analytics
# 16                               Another Day
# 17                                      Taro
# 18             Write This Down (feat. Nieve)
# 19                            Maybe Tomorrow
# 20                                    Anchor
# 21                             Under the Sun
# 22  Something About The Way You Look Tonight
# 23                             Beautiful Now
# 24                               Allein sein
# 25                                  So Young
# 26                                      Easy
# 27                              Out Of Touch
# 28                                   Okinawa
# 29                                These Days
# 30                         Is It Any Wonder?
# 31                       no song without you
# 32                              Rearrange Us
# 33                                Those Eyes
# 34                          Out Here with Us
# 35                              Kill Me Slow
# 36                             Lonely Nights
# 37                   To Let A Good Thing Die
# 38                                     Casio
# 39                                      Lady
# 40                   F*ckwithmeyouknowigotit
# 41                                Heat Waves
# 42                                  Memories
# 43                                    Fabric
# 44                               Real Estate
# 45                                 Left Side
# 46                                      gray
# 47            Slow Dancing in a Burning Room
# 48                              On Your Mind
# 49                                Paper Thin
#
#                                               album                track_id  \
# 0                        Dreamland (+ Bonus Levels)  3NAGZe9GWtE8Nvfj6huEzE
# 1                                           Elusive  4mbOTHs6heygME9uDHg0mf
# 2                                       Black Pumas  6J3HNhDBIwEX11bX8hzx5u
# 3                                     Blood Remixed  1hgX0ZmmP7IRRjUFCIBrnQ
# 4                                       Brown Sugar  3ibHHhuRj8od0hgKx0xHRb
# 5                                    The Difference  4nlvKIIetOWGIMyhjQXgOZ
# 6                                         Apollo 19  1oAMeG9XWoIHKG2nTAgTku
# 7                                  Only Ticket Home  79wvYwZgtfcnCwBI8XIep8
# 8                            This Must Be The Place  0EudqIdrpZjHZ1pnSuBKgA
# 9                                          dreamin'  4PlzJVdaRYC9Fg2AqlOxer
# 10                                     Rushing Back  2zoNNEAyPK2OGDfajardlY
# 11                                 Tum Saath Rehnaa  4Ft4Tj0l8kzfKBv8vGuR4t
# 12                          To Let A Good Thing Die  5unXHHcSQLGO19RuVqZB6d
# 13                              You're Too Precious  5teYCP3pROESCEaASCVf5w
# 15                      Tim'm West    375893           0
# 16                          DREEZE    239255           3
# 17                           alt-J    305106          43
# 18                        SoulChef    189426          73
# 19                   Stereophonics    272946          67
# 20                       Novo Amor    257533          73
# 21                      Omar Morto    175147          41
# 22                      Elton John    308840          53
# 23                            Zedd    218293          71
# 24                          Beyazz    198093          53
# 25               Portugal. The Man    246480          63
# 26                      Commodores    256426          76
# 27                       Lastlings    294280          28
# 28                           92914    348445          61
# 29                      Caleborate    219179          42
# 30  Durand Jones & The Indications    276600          59
# 31                           HONNE    160346          65
# 32                         Mt. Joy    188066          60
# 33                        New West    220750          53
# 34                  Parra for Cuva    247954          55
# 35                    David Guetta    208095          66
# 36                         LEISURE    200093          30
# 37                     Bruno Major    135013          52
# 38                          Jungle    234369          69
# 39                       Cloak Bay    239255          41
# 40                           JAY-Z    243413          55
# 41                   Glass Animals    238805          84
# 42                   Petit Biscuit    216032          55
# 43    Frankie Stew and Harvey Gunn    190413          43
# 44                    Adam Melchor    216000          63
# 45                          Eloise    144962          54
# 46                   slenderbodies    183157          53
# 47                      John Mayer    242000          75
# 48                         Kaskade    320280          65
# 49                 Lianne La Havas    298720          62

# %%
def fetch_audio_features(sp, df):
    playlist = df[['track_id','track_name']] 
    index = 0
    audio_features = []
    
    # Make the API request
    while index < playlist.shape[0]:
        audio_features += sp.audio_features(playlist.iloc[index:index + 50, 0])
        index += 50
    
    # Create an empty list to feed in different charactieritcs of the tracks
    features_list = []
    #Create keys-values of empty lists inside nested dictionary for album
    for features in audio_features:
        features_list.append([features['danceability'],
                              features['acousticness'],
                              features['energy'], 
                              features['tempo'],
                              features['instrumentalness'], 
                              features['loudness'],
                              features['liveness'],
                              features['duration_ms'],
                              features['key'],
                              features['valence'],
                              features['speechiness'],
                              features['mode']
                             ])
    
    df_audio_features = pd.DataFrame(features_list, columns=['danceability', 'acousticness', 'energy','tempo', 
                                                             'instrumentalness', 'loudness', 'liveness','duration_ms', 'key',
                                                             'valence', 'speechiness', 'mode'])
    
    # Create the final df, using the 'track_id' as index for future reference
    df_playlist_audio_features = pd.concat([playlist, df_audio_features], axis=1)
    df_playlist_audio_features.set_index('track_name', inplace=True, drop=True)
    return df_playlist_audio_features

# %%
df_fav = fetch_audio_features (sp, df_favourite)
df_fav
# Out:
#                                                         track_id  \
# track_name
# Your Love (Déjà Vu)                       3NAGZe9GWtE8Nvfj6huEzE
# Elusive                                   4mbOTHs6heygME9uDHg0mf
# Colors                                    6J3HNhDBIwEX11bX8hzx5u
# Feel Your Weight - Poolside Remix         1hgX0ZmmP7IRRjUFCIBrnQ
# Late Night                                3ibHHhuRj8od0hgKx0xHRb
# The Difference                            4nlvKIIetOWGIMyhjQXgOZ
# 25 Hours                                  1oAMeG9XWoIHKG2nTAgTku
# Always                                    79wvYwZgtfcnCwBI8XIep8
# Sirens                                    0EudqIdrpZjHZ1pnSuBKgA
# dreamin'                                  4PlzJVdaRYC9Fg2AqlOxer
# Rushing Back                              2zoNNEAyPK2OGDfajardlY
# Casio                                       0.0995       234370   10    0.765
# Lady                                        0.1100       239255    6    0.458
# F*ckwithmeyouknowigotit                     0.0794       243413   10    0.274
# Heat Waves                                  0.0921       238805   11    0.531
# Memories                                    0.1160       216033    1    0.536
# Fabric                                      0.0957       190413    7    0.115
# Real Estate                                 0.1510       216000    2    0.199
# Left Side                                   0.1860       144963    0    0.375
# gray                                        0.1700       183158    8    0.417
# Slow Dancing in a Burning Room              0.0805       242000    1    0.290
# On Your Mind                                0.0602       320280    4    0.178
# Paper Thin                                  0.1100       298720    0    0.504
#
#                                           speechiness  mode
# track_name
# Your Love (Déjà Vu)                            0.0532     1
# Elusive                                        0.2190     0
# Colors                                         0.0335     1
# Feel Your Weight - Poolside Remix              0.0308     0
# Late Night                                     0.0426     1
# The Difference                                 0.0909     1
# 25 Hours                                       0.0382     0
# Always                                         0.0293     1
# Sirens                                         0.0498     0
# dreamin'                                       0.4400     0
# Rushing Back                                   0.0781     1
# Tum Saath Rehnaa                               0.2940     1
# The Most Beautiful Thing                       0.0345     1
# You're Too Precious                            0.1400     1
# with you                                       0.0529     1
# Analytics                                      0.4110     0
# Another Day                                    0.1070     0
# Taro                                           0.0342     1
# Write This Down (feat. Nieve)                  0.1800     0
# Maybe Tomorrow                                 0.0361     0
# Anchor                                         0.0308     1
# Under the Sun                                  0.4280     0
# Something About The Way You Look Tonight       0.0268     1
# Beautiful Now                                  0.0282     0
# Allein sein                                    0.1210     0
# So Young                                       0.0291     0
# Easy                                           0.0332     0
# Out Of Touch                                   0.0342     0
# Okinawa                                        0.0567     1
# These Days                                     0.4390     1
# Is It Any Wonder?                              0.0296     0
# no song without you                            0.0328     1
# Rearrange Us                                   0.0263     1
# Those Eyes                                     0.0282     1
# Out Here with Us                               0.0346     0
# Kill Me Slow                                   0.0605     0
# Lonely Nights                                  0.0299     0
# To Let A Good Thing Die                        0.0978     1
# Casio                                          0.0752     0
# Lady                                           0.0507     0
# F*ckwithmeyouknowigotit                        0.2940     0
# Heat Waves                                     0.0944     1
# Memories                                       0.1030     0
# Fabric                                         0.0724     1
# Real Estate                                    0.0309     1
# Left Side                                      0.0849     1
# gray                                           0.1070     0
# Slow Dancing in a Burning Room                 0.0273     0
# On Your Mind                                   0.0949     0
# Paper Thin                                     0.0478     1

# %%
df_fav.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Your Love (Déjà Vu) to Paper Thin
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          50 non-null     object
#  1   danceability      50 non-null     float64
#  2   acousticness      50 non-null     float64
#  3   energy            50 non-null     float64
#  4   tempo             50 non-null     float64
#  5   instrumentalness  50 non-null     float64
#  6   loudness          50 non-null     float64
#  7   liveness          50 non-null     float64
#  8   duration_ms       50 non-null     int64
#  9   key               50 non-null     int64
#  10  valence           50 non-null     float64
#  11  speechiness       50 non-null     float64
#  12  mode              50 non-null     int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 5.5+ KB

# %%
df_fav.hist(figsize=(35,25)) 
plt.tight_layout()
plt.show()

# %%
response = sp.featured_playlists()
# check the format of the data 
response
# Out:
# {'message': "Editor's picks",
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?timestamp=2021-06-28T13%3A07%3A12&offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'A playlist to get you through your whole workday.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcsT4WKI8W8r'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcsT4WKI8W8r',
#     'id': '37i9dQZF1DXcsT4WKI8W8r',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000034de77acbe943df267598e50c',
#       'width': None}],
#     'name': 'Music for a Workday',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyNDg4NTYyNywwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcsT4WKI8W8r/tracks',
#      'total': 145},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcsT4WKI8W8r'},
#    {'collaborative': False,
#     'description': 'The biggest songs of the 1970s.\n',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTJ7xPn4vNaz'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTJ7xPn4vNaz',
#     'id': '37i9dQZF1DWTJ7xPn4vNaz',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003395fa4331871be34c70c4df5',
#       'width': None}],
#     'name': 'All Out 70s',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyNDg4NTYzMiwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTJ7xPn4vNaz/tracks',
#      'total': 150},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWTJ7xPn4vNaz'},
#    {'collaborative': False,
#     'description': 'New music from Tyler, The Creator, DaBaby and Ski Mask the Slump God.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0XUsuxWHRQd'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0XUsuxWHRQd',
#     'id': '37i9dQZF1DX0XUsuxWHRQd',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003353d8ac13fe0d9759b5167b6',
#       'width': None}],
#     'name': 'RapCaviar',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyNDU5MzYwMCwwMDAwMDVhMDAwMDAwMTdhNDE1MzBlYzgwMDAwMDE3YTNlOGFkZTU5',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0XUsuxWHRQd/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX0XUsuxWHRQd'},
#    {'collaborative': False,
#     'description': 'Focus-enhancing piano for your study session.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8NTLI2TtZa6'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8NTLI2TtZa6',
#     'id': '37i9dQZF1DX8NTLI2TtZa6',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000318e20d8d2bc7aa007d305e57',
#       'width': None}],
#     'name': 'Intense Studying',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyMzc2OTA4MywwMDAwMDA5OTAwMDAwMTdhMTAyZGVlMTkwMDAwMDE2ZDE1NDYxNzE3',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8NTLI2TtZa6/tracks',
#      'total': 213},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX8NTLI2TtZa6'},
#    {'collaborative': False,
#     'description': 'Mode: Turnt',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWY4xHQp97fN6'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWY4xHQp97fN6',
#     'id': '37i9dQZF1DWY4xHQp97fN6',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000030aa2cf87a0674e630eecb75f',
#       'width': None}],
#     'name': 'Get Turnt',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyNDU5MzYwMCwwMDAwMDRhYzAwMDAwMTdhNDE1MzBlYzMwMDAwMDE3OWYxYmMwZmMx',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWY4xHQp97fN6/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWY4xHQp97fN6'},
#    {'collaborative': False,
#     'description': 'Kick back to the best new and recent chill tunes.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4WYpdgoIcn6'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4WYpdgoIcn6',
#     'id': '37i9dQZF1DX4WYpdgoIcn6',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003cf8e264c6a92e245402ecb7a',
#       'width': None}],
#     'name': 'Chill Hits',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyNDg4NTU5MSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4WYpdgoIcn6/tracks',
#      'total': 130},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4WYpdgoIcn6'},
#    {'collaborative': False,
#     'description': 'Your daily dose of Soul-infused music! Cover: Leon Bridges',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSXWSaQmvWOB'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSXWSaQmvWOB',
#     'id': '37i9dQZF1DWSXWSaQmvWOB',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003bd3779e202cedefd7e6387c0',
#       'width': None}],
#     'name': "Soul 'n' the City",
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyNDg3MTE2MiwwMDAwMDBlYzAwMDAwMTdhNTFkZTUxMGEwMDAwMDE3OTllODVlNjIz',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSXWSaQmvWOB/tracks',
#      'total': 128},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWSXWSaQmvWOB'},
#    {'collaborative': False,
#     'description': 'These songs rocked the 90s. Cover: Nirvana',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1rVvRgjX59F'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1rVvRgjX59F',
#     'id': '37i9dQZF1DX1rVvRgjX59F',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003b6e605ef428ddef4b7ce24aa',
#       'width': None}],
#     'name': '90s Rock Anthems',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYwNDU3NjM4MiwwMDAwMDAxZTAwMDAwMTc1OTgzNDhmYjgwMDAwMDE3MGM0OTc1ZmRh',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1rVvRgjX59F/tracks',
#      'total': 150},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1rVvRgjX59F'},
#    {'collaborative': False,
#     'description': 'Unwind and let the afternoon unfold.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4E3UdUs7fUx'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4E3UdUs7fUx',
#     'id': '37i9dQZF1DX4E3UdUs7fUx',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000031cb21db1932b5c9139bbf136',
#       'width': None}],
#     'name': 'Afternoon Acoustic',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyNDg4NTYxMSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4E3UdUs7fUx/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4E3UdUs7fUx'},
#    {'collaborative': False,
#     'description': 'Laid back cratedigger hip-hop from around the world.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8Kgdykz6OKj'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8Kgdykz6OKj',
#     'id': '37i9dQZF1DX8Kgdykz6OKj',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000035115b9702d26cd841fda7827',
#       'width': None}],
#     'name': 'Jazz Rap',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTYyNDg4NTU4MywwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8Kgdykz6OKj/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX8Kgdykz6OKj'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 10}}

# %%
# Let's untangle the data
print(response['message'])
playlists = response['playlists']
# For looping through the API request
for i, item in enumerate(playlists['items']):
    print('no: {},Name: {},id: {}, description: {}, total tracks: {}'.
          format(playlists['offset'] + i, item['name'], item['id'],item['description'], item['tracks']['total']))
if playlists['next']:
    response = sp.next(playlists)
else:
    response = None
# Out:
# Editor's picks
# no: 0,Name: Music for a Workday,id: 37i9dQZF1DXcsT4WKI8W8r, description: A playlist to get you through your whole workday., total tracks: 145
# no: 1,Name: All Out 70s,id: 37i9dQZF1DWTJ7xPn4vNaz, description: The biggest songs of the 1970s.
# , total tracks: 150
# no: 2,Name: RapCaviar,id: 37i9dQZF1DX0XUsuxWHRQd, description: New music from Tyler, The Creator, DaBaby and Ski Mask the Slump God., total tracks: 50
# no: 3,Name: Intense Studying,id: 37i9dQZF1DX8NTLI2TtZa6, description: Focus-enhancing piano for your study session., total tracks: 213
# no: 4,Name: Get Turnt,id: 37i9dQZF1DWY4xHQp97fN6, description: Mode: Turnt, total tracks: 100
# no: 5,Name: Chill Hits,id: 37i9dQZF1DX4WYpdgoIcn6, description: Kick back to the best new and recent chill tunes., total tracks: 130
# no: 6,Name: Soul 'n' the City,id: 37i9dQZF1DWSXWSaQmvWOB, description: Your daily dose of Soul-infused music! Cover: Leon Bridges, total tracks: 128
# no: 7,Name: 90s Rock Anthems,id: 37i9dQZF1DX1rVvRgjX59F, description: These songs rocked the 90s. Cover: Nirvana, total tracks: 150
# no: 8,Name: Afternoon Acoustic,id: 37i9dQZF1DX4E3UdUs7fUx, description: Unwind and let the afternoon unfold., total tracks: 100
# no: 9,Name: Jazz Rap,id: 37i9dQZF1DX8Kgdykz6OKj, description: Laid back cratedigger hip-hop from around the world., total tracks: 100

# %%
def featured_playlists(sp):
    id = []
    name = []
    num_tracks = []
 # For looping through the API request  
    response = sp.featured_playlists()
    playlists = response['playlists']
    for i, items in enumerate(playlists['items']):
        id.append(items['id'])
        name.append(items['name'])
        num_tracks.append(items['tracks']['total'])

# Create the final df   
    df_playlists = pd.DataFrame({"id":id, "name": name, "#tracks": num_tracks})
    return df_playlists

# %%
df_playlists = featured_playlists(sp)
df_playlists
# Out:
#                        id                 name  #tracks
# 0  37i9dQZF1DXcsT4WKI8W8r  Music for a Workday      145
# 1  37i9dQZF1DWTJ7xPn4vNaz          All Out 70s      150
# 2  37i9dQZF1DX0XUsuxWHRQd            RapCaviar       50
# 3  37i9dQZF1DX8NTLI2TtZa6     Intense Studying      213
# 4  37i9dQZF1DWY4xHQp97fN6            Get Turnt      100
# 5  37i9dQZF1DX4WYpdgoIcn6           Chill Hits      130
# 6  37i9dQZF1DWSXWSaQmvWOB    Soul 'n' the City      128
# 7  37i9dQZF1DX1rVvRgjX59F     90s Rock Anthems      150
# 8  37i9dQZF1DX4E3UdUs7fUx   Afternoon Acoustic      100
# 9  37i9dQZF1DX8Kgdykz6OKj             Jazz Rap      100

# %%
def fetch_playlist_tracks(sp, playlistsid): 
    offset = 0
    tracks = []
    # Make the API request
    while True:
            content = sp.playlist_tracks( playlistsid, fields=None, limit=100, offset=offset, market=None)
            tracks += content['items']
        
            if content['next'] is not None:
                offset += 100
            else:
                break
    
    track_id = []
    track_name = []
    
    for track in tracks:
        track_id.append(track['track']['id'])
        track_name.append(track['track']['name'])
    
# Create the final df
    df_playlists_tracks = pd.DataFrame({"track_id":track_id, "track_name": track_name})
    return df_playlists_tracks

# %%
# Test the function
fetch_playlist_tracks(sp,'37i9dQZF1DX4WYpdgoIcn6')
# Out:
#                    track_id                                         track_name
# 0    6sgqf4wXFWSAmjL1TEXNvZ  Something About You (with Rudimental) - Chill Mix
# 1    6CDzDgIUqeDY5g8ujExx2f                                         Heat Waves
# 2    2Ee9amLUslOwgoJWZEpSSD                   Mystery Lady (feat. Don Toliver)
# 3    3NRql0A1Ef4RCvT473iqgD                                        Hell N Back
# 4    6Ed1q0X8oSKSm4IIhiQbYg                                           Daylight
# ..                      ...                                                ...
# 125  3cMAS9DjZHrAnKvPrTIw7Z                      Wait for You (feat. Zoe Wees)
# 126  55vsJO4tLZQ37qzD5QUOmh                              House With No Mirrors
# 127  47EWMOElkkbMp5m9SBkx7d                                        IDK You Yet
# 128  1Lmm7Nz42ecjZn2WZU64JA                                Dancing in the Dark
# 129  2gA74HvN6NKFrhgzpd5oNE                  Line By Line (feat. Maren Morris)
#
# [130 rows x 2 columns]

# %%
def fetch_audio_features(sp, playlist_id):
    playlist = fetch_playlist_tracks(sp, playlist_id)
    index = 0
    audio_features = []
    
    # Make the API request
    while index < playlist.shape[0]:
        audio_features += sp.audio_features(playlist.iloc[index:index + 50, 0])
        index += 50
    
    # Create an empty list to feed in different charactieritcs of the tracks
    features_list = []
    #Create keys-values of empty lists inside nested dictionary for album
    for features in audio_features:
        features_list.append([features['danceability'],
                              features['acousticness'],
                              features['energy'], 
                              features['tempo'],
                              features['instrumentalness'], 
                              features['loudness'],
                              features['liveness'],
                              features['duration_ms'],
                              features['key'],
                              features['valence'],
                              features['speechiness']
                             ])
    
    df_audio_features = pd.DataFrame(features_list, columns=['danceability', 'acousticness', 'energy','tempo', 
                                                             'instrumentalness', 'loudness', 'liveness', 'duration_ms', 'key',
                                                             'valence', 'speechiness'])
    
    # Create the final df, using the 'track_id' as index for future reference
    df_playlist_audio_features = pd.concat([playlist, df_audio_features], axis=1)
    df_playlist_audio_features.set_index('track_name', inplace=True, drop=True)
    return df_playlist_audio_features

# %%
# Build the dtaframe froms the playlists
for i, playlist in enumerate(df_playlists['id']):
    try:
        string_command = "df_{} = fetch_audio_features(sp, playlist)".format(playlist)
        print("Create {}".format(string_command))
        exec(string_command)
    except:
        print("playlist with id {} is not valid, skiping ".format(playlist))
        pass
# Out:
# Create df_37i9dQZF1DXcsT4WKI8W8r = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DWTJ7xPn4vNaz = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DX0XUsuxWHRQd = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DX8NTLI2TtZa6 = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DWY4xHQp97fN6 = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DX4WYpdgoIcn6 = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DWSXWSaQmvWOB = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DX1rVvRgjX59F = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DX4E3UdUs7fUx = fetch_audio_features(sp, playlist)
# Create df_37i9dQZF1DX8Kgdykz6OKj = fetch_audio_features(sp, playlist)

# %%
df_playlist_audio_features=fetch_audio_features(sp, '37i9dQZF1DX4WYpdgoIcn6')
df_playlist_audio_features
# Out:
#                                                                  track_id  \
# track_name
# Something About You (with Rudimental) - Chill Mix  6sgqf4wXFWSAmjL1TEXNvZ
# Heat Waves                                         6CDzDgIUqeDY5g8ujExx2f
# Mystery Lady (feat. Don Toliver)                   2Ee9amLUslOwgoJWZEpSSD
# Hell N Back                                        3NRql0A1Ef4RCvT473iqgD
# Daylight                                           6Ed1q0X8oSKSm4IIhiQbYg
# ...                                                                   ...
# Wait for You (feat. Zoe Wees)                      3cMAS9DjZHrAnKvPrTIw7Z
# House With No Mirrors                              55vsJO4tLZQ37qzD5QUOmh
# IDK You Yet                                        47EWMOElkkbMp5m9SBkx7d
# Dancing in the Dark                                1Lmm7Nz42ecjZn2WZU64JA
# Line By Line (feat. Maren Morris)                  2gA74HvN6NKFrhgzpd5oNE
#
#                                                    danceability  acousticness  \
# track_name
# Something About You (with Rudimental) - Chill Mix         0.800       0.36500
# Heat Waves                                                0.761       0.44000
# Mystery Lady (feat. Don Toliver)                          0.747       0.39300
# Hell N Back                                               0.584       0.31200
# Daylight                                                  0.528       0.00488
# ...                                                         ...           ...
# Wait for You (feat. Zoe Wees)                             0.502       0.36600
# House With No Mirrors                                     0.720       0.83200
# IDK You Yet                                               0.629       0.88400
# Dancing in the Dark                                       0.743       0.29100
# Line By Line (feat. Maren Morris)                         0.645       0.27400
#
#                                                    energy    tempo  \
# track_name
# Something About You (with Rudimental) - Chill Mix   0.516  106.122
# Heat Waves                                          0.525   80.870
# Mystery Lady (feat. Don Toliver)                    0.494   76.006
# Hell N Back                                         0.684  210.164
# Daylight                                            0.749  163.944
# ...                                                   ...      ...
# Wait for You (feat. Zoe Wees)                       0.650  159.780
# House With No Mirrors                               0.408  121.972
# IDK You Yet                                         0.306   76.994
# Dancing in the Dark                                 0.472  144.992
# Line By Line (feat. Maren Morris)                   0.486   72.536
#
#                                                    instrumentalness  loudness  \
# track_name
# Something About You (with Rudimental) - Chill Mix          0.002060    -8.076
# Heat Waves                                                 0.000007    -6.900
# Mystery Lady (feat. Don Toliver)                           0.000000    -7.957
# Hell N Back                                                0.000091    -4.314
# Daylight                                                   0.000096    -7.571
# ...                                                             ...       ...
# Wait for You (feat. Zoe Wees)                              0.000000    -4.270
# House With No Mirrors                                      0.000003   -11.725
# IDK You Yet                                                0.077600   -11.735
# Dancing in the Dark                                        0.000079    -8.957
# Line By Line (feat. Maren Morris)                          0.000000    -7.299
#
#                                                    liveness  duration_ms  key  \
# track_name
# Something About You (with Rudimental) - Chill Mix    0.1340       166534    6
# Heat Waves                                           0.0921       238805   11
# Mystery Lady (feat. Don Toliver)                     0.0982       228453    3
# Hell N Back                                          0.1120       213573   10
# Daylight                                             0.0949       163906    7
# ...                                                     ...          ...  ...
# Wait for You (feat. Zoe Wees)                        0.0956       153027    1
# House With No Mirrors                                0.0992       227613    2
# IDK You Yet                                          0.1240       184638    1
# Dancing in the Dark                                  0.0942       178472   11
# Line By Line (feat. Maren Morris)                    0.1350       208187    0
#
#                                                    valence  speechiness
# track_name
# Something About You (with Rudimental) - Chill Mix    0.443       0.1270
# Heat Waves                                           0.531       0.0944
# Mystery Lady (feat. Don Toliver)                     0.624       0.1410
# Hell N Back                                          0.720       0.5670
# Daylight                                             0.729       0.0479
# ...                                                    ...          ...
# Wait for You (feat. Zoe Wees)                        0.392       0.0531
# House With No Mirrors                                0.341       0.0498
# IDK You Yet                                          0.191       0.0424
# Dancing in the Dark                                  0.462       0.0996
# Line By Line (feat. Maren Morris)                    0.453       0.0425
#
# [130 rows x 12 columns]

# %%
def fetch_audio_features_mean(sp, playlist_id):
    Playlist = fetch_audio_features(sp, playlist_id)
    return pd.DataFrame(Playlist.mean(), columns= [playlist_id])

# %%
# Test the function
df = fetch_audio_features_mean(sp, '37i9dQZF1DX4WYpdgoIcn6')
df.head(10)
# Out:
#                   37i9dQZF1DX4WYpdgoIcn6
# danceability                    0.626662
# acousticness                    0.434660
# energy                          0.475631
# tempo                         117.359477
# instrumentalness                0.003572
# loudness                       -8.171169
# liveness                        0.151404
# duration_ms                194607.292308
# key                             5.130769
# valence                         0.386383

# %%
# Merge them together
dataframes = []
# Loop through the filenames to populate dataframes with different dataframes 
for  i in df_playlists['id']:
    dataframes.append(fetch_audio_features_mean(sp, i))

# %%
dataframes
# Out:
# [                  37i9dQZF1DXcsT4WKI8W8r
#  danceability                    0.647931
#  acousticness                    0.342690
#  energy                          0.554034
#  tempo                         113.998490
#  instrumentalness                0.026917
#  loudness                       -7.871634
#  liveness                        0.164878
#  duration_ms                193303.434483
#  key                             4.993103
#  valence                         0.455655
#  speechiness                     0.084343,
#                    37i9dQZF1DWTJ7xPn4vNaz
#  danceability                    0.619020
#  acousticness                    0.309289
#  energy                          0.583027
#  tempo                         117.423387
#  instrumentalness                0.037060
#  loudness                      -10.210873
#  liveness                        0.157343
#  duration_ms                251439.320000
#  key                             5.420000
#  valence                         0.681986
#  speechiness                     0.051987,
#                    37i9dQZF1DX0XUsuxWHRQd
#  danceability                    0.744140
#  acousticness                    0.145835
#  energy                          0.606140
#  tempo                         119.290800
#  instrumentalness                0.000170
#  loudness                       -6.892800
#  liveness                        0.174314
#  duration_ms                189943.120000
#  key                             4.840000
#  valence                         0.462846
#  speechiness                     0.251468,
#                    37i9dQZF1DX8NTLI2TtZa6
#  danceability                    0.368178
#  acousticness                    0.989160
#  energy                          0.056598
#  tempo                         119.497183
#  instrumentalness                0.912338
#  loudness                      -26.683188
#  liveness                        0.108163
#  duration_ms                152683.497653
#  key                             5.600939
#  valence                         0.228645
#  speechiness                     0.042138,
#                    37i9dQZF1DWY4xHQp97fN6
#  danceability                    0.814600
#  acousticness                    0.106624
#  energy                          0.612570
#  tempo                         125.783140
#  instrumentalness                0.005570
#  loudness                       -6.681840
#  liveness                        0.186525
#  duration_ms                180284.950000
#  key                             5.270000
#  valence                         0.516188
#  speechiness                     0.261911,
#                    37i9dQZF1DX4WYpdgoIcn6
#  danceability                    0.626662
#  acousticness                    0.434660
#  energy                          0.475631
#  tempo                         117.359477
#  instrumentalness                0.003572
#  loudness                       -8.171169
#  liveness                        0.151404
#  duration_ms                194607.292308
#  key                             5.130769
#  valence                         0.386383
#  speechiness                     0.081043,
#                    37i9dQZF1DWSXWSaQmvWOB
#  danceability                    0.663125
#  acousticness                    0.329767
#  energy                          0.553633
#  tempo                         112.752398
#  instrumentalness                0.044768
#  loudness                       -8.058000
#  liveness                        0.159355
#  duration_ms                222120.460938
#  key                             5.656250
#  valence                         0.575019
#  speechiness                     0.095416,
#                    37i9dQZF1DX1rVvRgjX59F
#  danceability                    0.466873
#  acousticness                    0.052690
#  energy                          0.760753
#  tempo                         124.946307
#  instrumentalness                0.078719
#  loudness                       -7.522880
#  liveness                        0.184483
#  duration_ms                251671.840000
#  key                             5.666667
#  valence                         0.524680
#  speechiness                     0.055589,
#                    37i9dQZF1DX4E3UdUs7fUx
#  danceability                    0.528760
#  acousticness                    0.771625
#  energy                          0.319944
#  tempo                         117.038010
#  instrumentalness                0.041828
#  loudness                      -11.925730
#  liveness                        0.136185
#  duration_ms                229636.070000
#  key                             4.990000
#  valence                         0.308544
#  speechiness                     0.034449,
#                    37i9dQZF1DX8Kgdykz6OKj
#  danceability                    0.685970
#  acousticness                    0.392745
#  energy                          0.582120
#  tempo                          98.765840
#  instrumentalness                0.018574
#  loudness                       -8.549440
#  liveness                        0.179789
#  duration_ms                200397.360000
#  key                             6.070000
#  valence                         0.551110
#  speechiness                     0.265704]

# %%
type(dataframes)
# Out:
# list

# %%
test_dataframes
# Out:
#                                                    0
# 0                    37i9dQZF1DXcsT4WKI8W8r
# dance...
# 1                    37i9dQZF1DWTJ7xPn4vNaz
# dance...
# 2                    37i9dQZF1DX0XUsuxWHRQd
# dance...
# 3                    37i9dQZF1DX8NTLI2TtZa6
# dance...
# 4                    37i9dQZF1DWY4xHQp97fN6
# dance...
# 5                    37i9dQZF1DX4WYpdgoIcn6
# dance...
# 6                    37i9dQZF1DWSXWSaQmvWOB
# dance...
# 7                    37i9dQZF1DX1rVvRgjX59F
# dance...
# 8                    37i9dQZF1DX4E3UdUs7fUx
# dance...
# 9                    37i9dQZF1DX8Kgdykz6OKj
# dance...

# %%
X = reduce(lambda left,right: pd.merge(left,right, left_index=True, right_index=True), dataframes)
X
# Out:
#                   37i9dQZF1DXcsT4WKI8W8r  37i9dQZF1DWTJ7xPn4vNaz  \
# danceability                    0.647931                0.619020
# acousticness                    0.342690                0.309289
# energy                          0.554034                0.583027
# tempo                         113.998490              117.423387
# instrumentalness                0.026917                0.037060
# loudness                       -7.871634              -10.210873
# liveness                        0.164878                0.157343
# duration_ms                193303.434483           251439.320000
# key                             4.993103                5.420000
# valence                         0.455655                0.681986
# speechiness                     0.084343                0.051987
#
#                   37i9dQZF1DX0XUsuxWHRQd  37i9dQZF1DX8NTLI2TtZa6  \
# danceability                    0.744140                0.368178
# acousticness                    0.145835                0.989160
# energy                          0.606140                0.056598
# tempo                         119.290800              119.497183
# instrumentalness                0.000170                0.912338
# loudness                       -6.892800              -26.683188
# liveness                        0.174314                0.108163
# duration_ms                189943.120000           152683.497653
# key                             4.840000                5.600939
# valence                         0.462846                0.228645
# speechiness                     0.251468                0.042138
#
#                   37i9dQZF1DWY4xHQp97fN6  37i9dQZF1DX4WYpdgoIcn6  \
# danceability                    0.814600                0.626662
# acousticness                    0.106624                0.434660
# energy                          0.612570                0.475631
# tempo                         125.783140              117.359477
# instrumentalness                0.005570                0.003572
# loudness                       -6.681840               -8.171169
# liveness                        0.186525                0.151404
# duration_ms                180284.950000           194607.292308
# key                             5.270000                5.130769
# valence                         0.516188                0.386383
# speechiness                     0.261911                0.081043
#
#                   37i9dQZF1DWSXWSaQmvWOB  37i9dQZF1DX1rVvRgjX59F  \
# danceability                    0.663125                0.466873
# acousticness                    0.329767                0.052690
# energy                          0.553633                0.760753
# tempo                         112.752398              124.946307
# instrumentalness                0.044768                0.078719
# loudness                       -8.058000               -7.522880
# liveness                        0.159355                0.184483
# duration_ms                222120.460938           251671.840000
# key                             5.656250                5.666667
# valence                         0.575019                0.524680
# speechiness                     0.095416                0.055589
#
#                   37i9dQZF1DX4E3UdUs7fUx  37i9dQZF1DX8Kgdykz6OKj
# danceability                    0.528760                0.685970
# acousticness                    0.771625                0.392745
# energy                          0.319944                0.582120
# tempo                         117.038010               98.765840
# instrumentalness                0.041828                0.018574
# loudness                      -11.925730               -8.549440
# liveness                        0.136185                0.179789
# duration_ms                229636.070000           200397.360000
# key                             4.990000                6.070000
# valence                         0.308544                0.551110
# speechiness                     0.034449                0.265704

# %%
Y = pd.DataFrame(df_fav.median(), columns= ['fav_playlist'])
Y= Y.drop('mode')
Y
# Out:
#                    fav_playlist
# danceability           0.683000
# acousticness           0.393500
# energy                 0.490500
# tempo                121.521500
# instrumentalness       0.010495
# loudness              -8.013500
# liveness               0.110000
# duration_ms       233016.500000
# key                    6.000000
# valence                0.422000
# speechiness            0.051800

# %%
# Analyze feature importances
from sklearn.ensemble.forest import RandomForestRegressor
# Can combine step above with this
forest = RandomForestRegressor(random_state=42, max_depth=5, max_features=10) 
forest.fit(X,Y)
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
# Print the feature rankings
print("Playlist ranking:")
  
for f in range(len(importances)):
    print("%d. %s %f " % (f + 1, 
            X.columns[f], 
            importances[indices[f]]))
# Out:
# Playlist ranking:
# 1. 37i9dQZF1DXcsT4WKI8W8r 0.200000
# 2. 37i9dQZF1DWTJ7xPn4vNaz 0.199286
# 3. 37i9dQZF1DX0XUsuxWHRQd 0.198840
# 4. 37i9dQZF1DX8NTLI2TtZa6 0.101117
# 5. 37i9dQZF1DWY4xHQp97fN6 0.100003
# 6. 37i9dQZF1DX4WYpdgoIcn6 0.100001
# 7. 37i9dQZF1DWSXWSaQmvWOB 0.100000
# 8. 37i9dQZF1DX1rVvRgjX59F 0.000754
# 9. 37i9dQZF1DX4E3UdUs7fUx 0.000000
# 10. 37i9dQZF1DX8Kgdykz6OKj 0.000000
# C:\Users\Himansh\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Himansh\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """

# %%
frames = [df_37i9dQZF1DXcsT4WKI8W8r, df_37i9dQZF1DWTJ7xPn4vNaz, df_37i9dQZF1DX0XUsuxWHRQd]
df =pd.concat(frames)
df
# Out:
#                                                      track_id  danceability  \
# track_name
# Your Man                               6Vgtvd7I5yopJdBuxqjBd2         0.785
# Low                                    52AlJfHPhlkY7OGrb2AjeQ         0.651
# Bonafide (feat. Chiiild)               5AHSYSrni7xVCzlanStMRf         0.724
# BS                                     1qxZswAdBvM0JMUoV83J1b         0.616
# Find an Island                         4DnKssL3N9jv5aox9Xsavc         0.836
# ...                                                       ...           ...
# Seeing Green (with Drake & Lil Wayne)  1TZv3bujNaYz646eezRE91         0.573
# She Make It Clap                       0kswxxNV4DLBqJeMIqFh5n         0.941
# 24 Hours (feat. Lil Durk)              0YH1xT3Z7wR6dZyaCwSziK         0.586
# Fractions                              28PeqNMnFfVQnXvXmyf88G         0.924
# Twerkulator                            2Ty7EDf9XLYzEUqEIwJfDC         0.895
#
#                                        acousticness  energy    tempo  \
# track_name
# Your Man                                     0.6240   0.818  117.980
# Low                                          0.1310   0.533   79.538
# Bonafide (feat. Chiiild)                     0.5160   0.439   98.009
# BS                                           0.5030   0.458   79.574
# Find an Island                               0.2850   0.681   81.566
# ...                                             ...     ...      ...
# Seeing Green (with Drake & Lil Wayne)        0.0853   0.867   74.861
# She Make It Clap                             0.0308   0.471  119.898
# 24 Hours (feat. Lil Durk)                    0.3340   0.474   91.105
# Fractions                                    0.0110   0.523  131.892
# Twerkulator                                  0.0012   0.469  126.917
#
#                                        instrumentalness  loudness  liveness  \
# track_name
# Your Man                                       0.149000    -8.711    0.1490
# Low                                            0.181000    -8.726    0.1580
# Bonafide (feat. Chiiild)                       0.043300   -10.350    0.0478
# BS                                             0.003500   -11.832    0.1150
# Find an Island                                 0.000000    -3.793    0.0727
# ...                                                 ...       ...       ...
# Seeing Green (with Drake & Lil Wayne)          0.000000    -2.876    0.3800
# She Make It Clap                               0.008380   -13.087    0.0837
# 24 Hours (feat. Lil Durk)                      0.000000    -9.210    0.1180
# Fractions                                      0.000000    -6.362    0.1700
# Twerkulator                                    0.000046    -5.882    0.1920
#
#                                        duration_ms  key  valence  speechiness
# track_name
# Your Man                                    163759    7   0.0503       0.0990
# Low                                         274424    1   0.5730       0.0592
# Bonafide (feat. Chiiild)                    177409    2   0.5690       0.0718
# BS                                          133987    3   0.5300       0.0455
# Find an Island                              192667    2   0.8520       0.0450
# ...                                            ...  ...      ...          ...
# Seeing Green (with Drake & Lil Wayne)       339506    5   0.2310       0.1680
# She Make It Clap                            111550    1   0.4870       0.4940
# 24 Hours (feat. Lil Durk)                   205702    2   0.1460       0.1800
# Fractions                                   181690    0   0.1440       0.1320
# Twerkulator                                 138542    1   0.0760       0.0661
#
# [345 rows x 12 columns]

# %%
df = df.set_index(['track_id'])
df
# Out:
#                         danceability  acousticness  energy    tempo  \
# track_id
# 6Vgtvd7I5yopJdBuxqjBd2         0.785        0.6240   0.818  117.980
# 52AlJfHPhlkY7OGrb2AjeQ         0.651        0.1310   0.533   79.538
# 5AHSYSrni7xVCzlanStMRf         0.724        0.5160   0.439   98.009
# 1qxZswAdBvM0JMUoV83J1b         0.616        0.5030   0.458   79.574
# 4DnKssL3N9jv5aox9Xsavc         0.836        0.2850   0.681   81.566
# ...                              ...           ...     ...      ...
# 1TZv3bujNaYz646eezRE91         0.573        0.0853   0.867   74.861
# 0kswxxNV4DLBqJeMIqFh5n         0.941        0.0308   0.471  119.898
# 0YH1xT3Z7wR6dZyaCwSziK         0.586        0.3340   0.474   91.105
# 28PeqNMnFfVQnXvXmyf88G         0.924        0.0110   0.523  131.892
# 2Ty7EDf9XLYzEUqEIwJfDC         0.895        0.0012   0.469  126.917
#
#                         instrumentalness  loudness  liveness  duration_ms  \
# track_id
# 6Vgtvd7I5yopJdBuxqjBd2          0.149000    -8.711    0.1490       163759
# 52AlJfHPhlkY7OGrb2AjeQ          0.181000    -8.726    0.1580       274424
# 5AHSYSrni7xVCzlanStMRf          0.043300   -10.350    0.0478       177409
# 1qxZswAdBvM0JMUoV83J1b          0.003500   -11.832    0.1150       133987
# 4DnKssL3N9jv5aox9Xsavc          0.000000    -3.793    0.0727       192667
# ...                                  ...       ...       ...          ...
# 1TZv3bujNaYz646eezRE91          0.000000    -2.876    0.3800       339506
# 0kswxxNV4DLBqJeMIqFh5n          0.008380   -13.087    0.0837       111550
# 0YH1xT3Z7wR6dZyaCwSziK          0.000000    -9.210    0.1180       205702
# 28PeqNMnFfVQnXvXmyf88G          0.000000    -6.362    0.1700       181690
# 2Ty7EDf9XLYzEUqEIwJfDC          0.000046    -5.882    0.1920       138542
#
#                         key  valence  speechiness
# track_id
# 6Vgtvd7I5yopJdBuxqjBd2    7   0.0503       0.0990
# 52AlJfHPhlkY7OGrb2AjeQ    1   0.5730       0.0592
# 5AHSYSrni7xVCzlanStMRf    2   0.5690       0.0718
# 1qxZswAdBvM0JMUoV83J1b    3   0.5300       0.0455
# 4DnKssL3N9jv5aox9Xsavc    2   0.8520       0.0450
# ...                     ...      ...          ...
# 1TZv3bujNaYz646eezRE91    5   0.2310       0.1680
# 0kswxxNV4DLBqJeMIqFh5n    1   0.4870       0.4940
# 0YH1xT3Z7wR6dZyaCwSziK    2   0.1460       0.1800
# 28PeqNMnFfVQnXvXmyf88G    0   0.1440       0.1320
# 2Ty7EDf9XLYzEUqEIwJfDC    1   0.0760       0.0661
#
# [345 rows x 11 columns]

# %%
# CO
Y= Y.squeeze('columns')

# %%
Y = Y.sort_index( axis=0, level=None, ascending=True, inplace=False, kind='quicksort')
Y
# Out:
# acousticness             0.393500
# danceability             0.683000
# duration_ms         233016.500000
# energy                   0.490500
# instrumentalness         0.010495
# key                      6.000000
# liveness                 0.110000
# loudness                -8.013500
# speechiness              0.051800
# tempo                  121.521500
# valence                  0.422000
# Name: fav_playlist, dtype: float64

# %%
# Subtract mean of the favourite plalyist from the top 3 playlist 
df1= df.subtract(Y, axis='columns') 
df1
# Out:
#                         acousticness  danceability  duration_ms  energy  \
# track_id
# 6Vgtvd7I5yopJdBuxqjBd2        0.2305         0.102     -69257.5  0.3275
# 52AlJfHPhlkY7OGrb2AjeQ       -0.2625        -0.032      41407.5  0.0425
# 5AHSYSrni7xVCzlanStMRf        0.1225         0.041     -55607.5 -0.0515
# 1qxZswAdBvM0JMUoV83J1b        0.1095        -0.067     -99029.5 -0.0325
# 4DnKssL3N9jv5aox9Xsavc       -0.1085         0.153     -40349.5  0.1905
# ...                              ...           ...          ...     ...
# 1TZv3bujNaYz646eezRE91       -0.3082        -0.110     106489.5  0.3765
# 0kswxxNV4DLBqJeMIqFh5n       -0.3627         0.258    -121466.5 -0.0195
# 0YH1xT3Z7wR6dZyaCwSziK       -0.0595        -0.097     -27314.5 -0.0165
# 28PeqNMnFfVQnXvXmyf88G       -0.3825         0.241     -51326.5  0.0325
# 2Ty7EDf9XLYzEUqEIwJfDC       -0.3923         0.212     -94474.5 -0.0215
#
#                         instrumentalness  key  liveness  loudness  \
# track_id
# 6Vgtvd7I5yopJdBuxqjBd
# track_id
# 6Vgtvd7I5yopJdBuxqjBd2     0.911197 -0.029143 -0.880806
# 52AlJfHPhlkY7OGrb2AjeQ     0.142857 -0.345482  0.357820
# 5AHSYSrni7xVCzlanStMRf     0.386100 -0.193484  0.348341
# 1qxZswAdBvM0JMUoV83J1b    -0.121622 -0.345186  0.255924
# 4DnKssL3N9jv5aox9Xsavc    -0.131274 -0.328794  1.018957
# ...                             ...       ...       ...
# 1TZv3bujNaYz646eezRE91     2.243243 -0.383969 -0.452607
# 0kswxxNV4DLBqJeMIqFh5n     8.536680 -0.013360  0.154028
# 0YH1xT3Z7wR6dZyaCwSziK     2.474903 -0.250297 -0.654028
# 28PeqNMnFfVQnXvXmyf88G     1.548263  0.085339 -0.658768
# 2Ty7EDf9XLYzEUqEIwJfDC     0.276062  0.044400 -0.819905
#
# [345 rows x 11 columns]

# %%
# Add all the score 
df1['variation'] = df1.sum(axis=1)
# take the absoulte of the variatio
df1['variation'] = df1['variation'].abs()
df1
# Out:
#                         acousticness  danceability  duration_ms    energy  \
# track_id
# 6Vgtvd7I5yopJdBuxqjBd2      0.585769      0.149341    -0.297221  0.667686
# 52AlJfHPhlkY7OGrb2AjeQ     -0.667090     -0.046852     0.177702  0.086646
# 5AHSYSrni7xVCzlanStMRf      0.311309      0.060029    -0.238642 -0.104995
# 1qxZswAdBvM0JMUoV83J1b      0.278272     -0.098097    -0.424989 -0.066259
# 4DnKssL3N9jv5aox9Xsavc     -0.275731      0.224012    -0.173162  0.388379
# ...                              ...           ...          ...       ...
# 1TZv3bujNaYz646eezRE91     -0.783227     -0.161054     0.457004  0.767584
# 0kswxxNV4DLBqJeMIqFh5n     -0.921728      0.377745    -0.521279 -0.039755
# 0YH1xT3Z7wR6dZyaCwSziK     -0.151207     -0.142020    -0.117221 -0.033639
# 28PeqNMnFfVQnXvXmyf88G     -0.972046      0.352855    -0.220270  0.066259
# 2Ty7EDf9XLYzEUqEIwJfDC     -0.996950      0.310395    -0.405441 -0.043833
#
#                         instrumentalness       key  liveness  loudness  \
# track_id
# 6Vgtvd7I5yopJdBuxqjBd2         13.197237  0.166667  0.354545  0.087041
# 52AlJfHPhlkY7OGrb2AjeQ         16.246308 -0.833333  0.436364  0.088912
# 5AHSYSrni7xVCzlanStMRf          3.125774 -0.666667 -0.565455  0.291570
# 1qxZswAdBvM0JMUoV83J1b         -0.666508 -0.500000  0.045455  0.476508
# 4DnKssL3N9jv5aox9Xsavc         -1.000000 -0.666667 -0.339091 -0.526674
# ...                                  ...       ...       ...       ...
# 1TZv3bujNaYz646eezRE91         -1.000000 -0.166667  2.454545 -0.641106
# 0kswxxNV4DLBqJeMIqFh5n         -0.201525 -0.833333 -0.239091  0.633119
# 0YH1xT3Z7wR6dZyaCwSziK         -1.000000 -0.666667  0.072727  0.149311
# 28PeqNMnFfVQnXvXmyf88G         -1.000000 -1.000000  0.545455 -0.206090
# 0hVZCUZKWsWFU6i5zlRZZr    -0.285714 -0.053608 -0.516588   0.137280
# 683b4ikwa62JevCjwrmfg6    -0.345560 -0.445292  0.334123   0.139386
# 5p3JunprHCxClJjOmcLV8G     1.104247 -0.139889 -0.087678   0.149312
# 094OGVJzllUzmdLvA31GqU     0.052124 -0.218468 -0.037915   0.150874
# 38N1GZG7AMdFaXLRTbwFc4     0.113900 -0.182416  0.834123   0.158547
# 5spAjqC772iC2KzDvEkmSr    -0.305019 -0.175487 -0.829621   0.168302
# 5DQAHkO9U4IZIombHefcqK    -0.380309 -0.037405  1.225118   0.177021
# 557cxXIeiwh03kI2F2jKdh     0.239382 -0.313159  0.253555   0.182801
# 6QTPacyXkZWG9FMwq6L1hJ    -0.376448 -0.070181  0.947867   0.196974
# 2L6lh2RmMs1yz4FQzdbwOn     2.069498  0.317512 -0.196682   0.201976
# 45fAUkBTqnLogZ0tRDchFi    -0.312741 -0.218731  0.007109   0.203472
# 4pNiE4LCVV74vfIBaUHm1b     0.297297 -0.120008  1.255924   0.203676
# 5sh7DKRH3YICFDDAVHVcUs    -0.332046  0.381937  0.457346   0.210490
# 0PDCewmZCp0P5s00bptcdd    -0.189189  0.042935  1.123223   0.217201
# 3frUvGrmGcay91lvFbOgsN     1.200772 -0.135758 -0.146919   0.267455
# 7rq1zCf90CnU7OalBLIgNp    -0.279923  0.152166 -0.220379   0.275511
# 4ZaAmweDaiOpbkLPty81Zw    -0.017375 -0.013212  0.502370   0.295333
# 1k1Bqnv2R0uJXQN4u6LKYt     1.355212 -0.356748  0.220379   0.304365
# 4twhYPDyCP6ICeW3TtQVxP    -0.198842 -0.172838 -0.260664   0.305880
# 5LV3AJZ7KOKCpoou8kny79    -0.492278 -0.325008  0.587678   0.306497
# 2IOFZdYYkFxEHVz1w34PoL    -0.500000 -0.210461 -0.026066   0.314794
# 07eItU09fRMPIgAqBY61TB     2.088803 -0.177158  0.199052   0.317738
# 0YH1xT3Z7wR6dZyaCwSziK     2.474903 -0.250297 -0.654028   0.318139
# 1lmfsSEuxU4PpT739Kihno    -0.144788 -0.140983  1.258294   0.319050
# 4AHIgOApMmqVfpvc1hxK6x    -0.364865 -0.029423 -0.810427   0.335630
# 170yBuCB3FvhMG2DMSQ4IG     0.440154 -0.103130  0.644550   0.338030
# 3X2r2CnHOJeV5YekPTgBnK     0.969112  0.118946 -0.741706   0.346882
# 63xdwScd1Ai1GigAwQxE8y     0.007722 -0.160766  0.201422   0.359418
# 7kStxK6rzxka5SRlg1lzhz    -0.200772  0.168954  0.518957   0.371687
# 5WwRKYnVy9dekqXAGPbAvU    -0.150579 -0.068116  0.985782   0.384340
# 5fxJc8fxbbM5ZiqaL6Ob6y    -0.413127  0.549973  0.263033   0.396057
# 62ljuuXo0zrcrtJnnOhfxT    -0.090734 -0.045848 -0.462085   0.399345
# 1tL5a9jowsWMtn3wkFYsG9    -0.069498 -0.334603  1.063981   0.400681

# %% [markdown]
# ## Create the playlist

# %%
def create_playlist(sp, username, playlist_name, playlist_description):
    playlists = sp.user_playlist_create(username, playlist_name, description = playlist_description)

# %%
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/browse/featured-playlists?timestamp=2021-06-28T13%3A07%3A12&offset=0&limit=20',
#  'items': [{'collaborative': False,
#    'description': 'A playlist to get you through your whole workday.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcsT4WKI8W8r'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcsT4WKI8W8r',
#    'id': '37i9dQZF1DXcsT4WKI8W8r',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000034de77acbe943df267598e50c',
#      'width': None}],
#    'name': 'Music for a Workday',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyNDg4NTYyNywwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcsT4WKI8W8r/tracks',
#     'total': 145},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DXcsT4WKI8W8r'},
#   {'collaborative': False,
#    'description': 'The biggest songs of the 1970s.\n',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTJ7xPn4vNaz'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTJ7xPn4vNaz',
#    'id': '37i9dQZF1DWTJ7xPn4vNaz',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003395fa4331871be34c70c4df5',
#      'width': None}],
#    'name': 'All Out 70s',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyNDg4NTYzMiwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTJ7xPn4vNaz/tracks',
#     'total': 150},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWTJ7xPn4vNaz'},
#   {'collaborative': False,
#    'description': 'New music from Tyler, The Creator, DaBaby and Ski Mask the Slump God.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0XUsuxWHRQd'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0XUsuxWHRQd',
#    'id': '37i9dQZF1DX0XUsuxWHRQd',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003353d8ac13fe0d9759b5167b6',
#      'width': None}],
#    'name': 'RapCaviar',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyNDU5MzYwMCwwMDAwMDVhMDAwMDAwMTdhNDE1MzBlYzgwMDAwMDE3YTNlOGFkZTU5',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0XUsuxWHRQd/tracks',
#     'total': 50},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX0XUsuxWHRQd'},
#   {'collaborative': False,
#    'description': 'Focus-enhancing piano for your study session.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8NTLI2TtZa6'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8NTLI2TtZa6',
#    'id': '37i9dQZF1DX8NTLI2TtZa6',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f0000000318e20d8d2bc7aa007d305e57',
#      'width': None}],
#    'name': 'Intense Studying',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyMzc2OTA4MywwMDAwMDA5OTAwMDAwMTdhMTAyZGVlMTkwMDAwMDE2ZDE1NDYxNzE3',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8NTLI2TtZa6/tracks',
#     'total': 213},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX8NTLI2TtZa6'},
#   {'collaborative': False,
#    'description': 'Mode: Turnt',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWY4xHQp97fN6'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWY4xHQp97fN6',
#    'id': '37i9dQZF1DWY4xHQp97fN6',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000030aa2cf87a0674e630eecb75f',
#      'width': None}],
#    'name': 'Get Turnt',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyNDU5MzYwMCwwMDAwMDRhYzAwMDAwMTdhNDE1MzBlYzMwMDAwMDE3OWYxYmMwZmMx',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWY4xHQp97fN6/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWY4xHQp97fN6'},
#   {'collaborative': False,
#    'description': 'Kick back to the best new and recent chill tunes.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4WYpdgoIcn6'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4WYpdgoIcn6',
#    'id': '37i9dQZF1DX4WYpdgoIcn6',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003cf8e264c6a92e245402ecb7a',
#      'width': None}],
#    'name': 'Chill Hits',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyNDg4NTU5MSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4WYpdgoIcn6/tracks',
#     'total': 130},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX4WYpdgoIcn6'},
#   {'collaborative': False,
#    'description': 'Your daily dose of Soul-infused music! Cover: Leon Bridges',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSXWSaQmvWOB'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSXWSaQmvWOB',
#    'id': '37i9dQZF1DWSXWSaQmvWOB',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003bd3779e202cedefd7e6387c0',
#      'width': None}],
#    'name': "Soul 'n' the City",
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyNDg3MTE2MiwwMDAwMDBlYzAwMDAwMTdhNTFkZTUxMGEwMDAwMDE3OTllODVlNjIz',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSXWSaQmvWOB/tracks',
#     'total': 128},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWSXWSaQmvWOB'},
#   {'collaborative': False,
#    'description': 'These songs rocked the 90s. Cover: Nirvana',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1rVvRgjX59F'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1rVvRgjX59F',
#    'id': '37i9dQZF1DX1rVvRgjX59F',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003b6e605ef428ddef4b7ce24aa',
#      'width': None}],
#    'name': '90s Rock Anthems',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYwNDU3NjM4MiwwMDAwMDAxZTAwMDAwMTc1OTgzNDhmYjgwMDAwMDE3MGM0OTc1ZmRh',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1rVvRgjX59F/tracks',
#     'total': 150},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX1rVvRgjX59F'},
#   {'collaborative': False,
#    'description': 'Unwind and let the afternoon unfold.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4E3UdUs7fUx'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4E3UdUs7fUx',
#    'id': '37i9dQZF1DX4E3UdUs7fUx',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000031cb21db1932b5c9139bbf136',
#      'width': None}],
#    'name': 'Afternoon Acoustic',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyNDg4NTYxMSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4E3UdUs7fUx/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX4E3UdUs7fUx'},
#   {'collaborative': False,
#    'description': 'Laid back cratedigger hip-hop from around the world.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8Kgdykz6OKj'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8Kgdykz6OKj',
#    'id': '37i9dQZF1DX8Kgdykz6OKj',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000035115b9702d26cd841fda7827',
#      'width': None}],
#    'name': 'Jazz Rap',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
#    'snapshot_id': 'MTYyNDg4NTU4MywwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8Kgdykz6OKj/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX8Kgdykz6OKj'}],
#  'limit': 20,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 10}

# %%
# Once the Authorisation is complete, we just need to `sp` to call the APIs
scope = 'user-read-private'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, redirect_uri=redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
create_playlist(sp, username, 'DJ Mishra', 'Created using python! Date: 29-Jun-21 01:05:43')
# Out:
# HTTP Error for POST to https://api.spotify.com/v1/users/spartan_147/playlists returned 403 due to Insufficient client scope
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/users/spartan_147/playlists
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-64-304d9bd0248d> in <module>
# ----> 1 create_playlist(sp, username, 'DJ Mishra', 'Created using python! Date: 29-Jun-21 01:05:43')
#
# <ipython-input-53-b4cdf73fea5d> in create_playlist(sp, username, playlist_name, playlist_description)
#       1 def create_playlist(sp, username, playlist_name, playlist_description):
# ----> 2     playlists = sp.user_playlist_create(username, playlist_name, description = playlist_description)
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in user_playlist_create(self, user, name, public, collaborative, description)
#     776         }
#     777
# --> 778         return self._post("users/%s/playlists" % (user,), payload=data)
#     779
#     780     def user_playlist_change_details(
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _post(self, url, args, payload, **kwargs)
#     294         if args:
#     295             kwargs.update(args)
# --> 296         return self._internal_call("POST", url, payload, kwargs)
#     297
#     298     def _delete(self, url, args=None, payload=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     264                 "%s:\n %s" % (response.url, msg),
#     265                 reason=reason,
# --> 266                 headers=response.headers,
#     267             )
#     268         except requests.exceptions.RetryError as retry_error:
#
# SpotifyException: http status: 403, code:-1 - https://api.spotify.com/v1/users/spartan_147/playlists:
#  Insufficient client scope, reason: None

# %%
def fetch_playlists(sp, username):
    """
    Returns the user's playlists.
    """
        
    id = []
    name = []
    num_tracks = []
    
    # Make the API request
    playlists = sp.user_playlists(username)
    for playlist in playlists['items']:
        id.append(playlist['id'])
        name.append(playlist['name'])
        num_tracks.append(playlist['tracks']['total'])

    # Create the final df   
    df_playlists = pd.DataFrame({"id":id, "name": name, "#tracks": num_tracks})
    return df_playlists

# %%
fetch_playlists(sp,username)
# Out:
#                         id                 name  #tracks
# 0   3caAs4FYA1S3oLRyZWTbe8         Chill (desi)       28
# 1   6bIbdQhK16uOaxM1gOY04y         Chill (gold)       23
# 2   6njSCwzVQkTXp3vEmQoROk          Chill (Alt)        4
# 3   360UHIwMNRVP0aWVxz7y0t         Roadtrip lol       10
# 4   4P9l3HXWB9Y3zVKKOhx74V       Easy listening       50
# 5   1JHqQ8TEC2kzm6Zzc2HPuk              L'Oréal       12
# 6   309IIeWYQLMzHOIfOaVv4L                 2013       40
# 7   4Mfs8GvZqLiAjKnUpltmrO         Work (Fresh)       56
# 8   6AIFiP7MEdwkP0rkNQLyRr         Work (Metal)        9
# 9   68r4ADlrZegD9vk80PlshG           Work (राग)       44
# 10  76Alc6q8G4zEW44D5eo5aH        Work (عربية)        19
# 11  6TziKbzDuDYO4Lvz4efBjR          Work (Rock)       41
# 12  21Mru2cojZv1s6Szi50Fcj    Work (Electronic)       55
# 13  6Tp2pmhbFYAHXz37Kco5PP         Work (Beats)       72
# 14  1IcvgxjmhAZdOqKZsf3dNo       Work (Workout)      130
# 15  4WViK78Yu84tGBMkJWBHCu        Chill (Blues)       12
# 16  71sptN1hnXsNdPwSDJFEOP       Chill (हिन्दी)       39
# 17  0wk04970vw4FTymrnaJ3NE   Chill (Electronic)       54
# 18  1ECPEhP0VLdiirsidcU5sm         Chill (Jazz)       24
# 19  3MwH847xpuXhsTaJEJ3ZEy  Chill (Alternative)       25
# 20  5rHrcZZZfXsZBgnDIqX8DL      Chill (Hip-hop)       49
# 21  5UpJNYIIyU7SPbGNvwmXhi          Chill (Pop)       83
# 22  6srXVFv8pZJIFtcueHEPHz         Chill (Surf)       74

# %%
def enrich_playlist(sp, username, playlist_id, playlist_tracks):
    index = 0
    results = []
    
    while index < len(playlist_tracks):
        results += sp.user_playlist_add_tracks(username, playlist_id, tracks = playlist_tracks[index:index + 50])
        index += 50

# %%
list_track = df2.index

# %%
enrich_playlist(sp, username, '2JKyl30f27MCwJ3oeH0elT', list_track)
# Out:
# HTTP Error for POST to https://api.spotify.com/v1/playlists/2JKyl30f27MCwJ3oeH0elT/tracks returned 403 due to Insufficient client scope
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/playlists/2JKyl30f27MCwJ3oeH0elT/tracks
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-67-2178e574d022> in <module>
# ----> 1 enrich_playlist(sp, username, '2JKyl30f27MCwJ3oeH0elT', list_track)
#
# <ipython-input-65-8903f840e364> in enrich_playlist(sp, username, playlist_id, playlist_tracks)
#       4
#       5     while index < len(playlist_tracks):
# ----> 6         results += sp.user_playlist_add_tracks(username, playlist_id, tracks = playlist_tracks[index:index + 50])
#       7         index += 50
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in user_playlist_add_tracks(self, user, playlist_id, tracks, position)
#     833                 - position - the position to add the tracks
#     834         """
# --> 835         return self.playlist_add_items(playlist_id, tracks, position)
#     836
#     837     def user_playlist_replace_tracks(self, user, playlist_id, tracks):
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in playlist_add_items(self, playlist_id, items, position)
#    1026             "playlists/%s/tracks" % (plid),
#    1027             payload=ftracks,
# -> 1028             position=position,
#    1029         )
#    1030
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _post(self, url, args, payload, **kwargs)
#     294         if args:
#     295             kwargs.update(args)
# --> 296         return self._internal_call("POST", url, payload, kwargs)
#     297
#     298     def _delete(self, url, args=None, payload=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     264                 "%s:\n %s" % (response.url, msg),
#     265                 reason=reason,
# --> 266                 headers=response.headers,
#     267             )
#     268         except requests.exceptions.RetryError as retry_error:
#
# SpotifyException: http status: 403, code:-1 - https://api.spotify.com/v1/playlists/2JKyl30f27MCwJ3oeH0elT/tracks:
#  Insufficient client scope, reason: None

# %%
fetch_playlists(sp,username)
# Out:
#                         id                 name  #tracks
# 0   3caAs4FYA1S3oLRyZWTbe8         Chill (desi)       28
# 1   6bIbdQhK16uOaxM1gOY04y         Chill (gold)       23
# 2   6njSCwzVQkTXp3vEmQoROk          Chill (Alt)        4
# 3   360UHIwMNRVP0aWVxz7y0t         Roadtrip lol       10
# 4   4P9l3HXWB9Y3zVKKOhx74V       Easy listening       50
# 5   1JHqQ8TEC2kzm6Zzc2HPuk              L'Oréal       12
# 6   309IIeWYQLMzHOIfOaVv4L                 2013       40
# 7   4Mfs8GvZqLiAjKnUpltmrO         Work (Fresh)       56
# 8   6AIFiP7MEdwkP0rkNQLyRr         Work (Metal)        9
# 9   68r4ADlrZegD9vk80PlshG           Work (राग)       44
# 10  76Alc6q8G4zEW44D5eo5aH        Work (عربية)        19
# 11  6TziKbzDuDYO4Lvz4efBjR          Work (Rock)       41
# 12  21Mru2cojZv1s6Szi50Fcj    Work (Electronic)       55
# 13  6Tp2pmhbFYAHXz37Kco5PP         Work (Beats)       72
# 14  1IcvgxjmhAZdOqKZsf3dNo       Work (Workout)      130
# 15  4WViK78Yu84tGBMkJWBHCu        Chill (Blues)       12
# 16  71sptN1hnXsNdPwSDJFEOP       Chill (हिन्दी)       39
# 17  0wk04970vw4FTymrnaJ3NE   Chill (Electronic)       54
# 18  1ECPEhP0VLdiirsidcU5sm         Chill (Jazz)       24
# 19  3MwH847xpuXhsTaJEJ3ZEy  Chill (Alternative)       25
# 20  5rHrcZZZfXsZBgnDIqX8DL      Chill (Hip-hop)       49
# 21  5UpJNYIIyU7SPbGNvwmXhi          Chill (Pop)       83
# 22  6srXVFv8pZJIFtcueHEPHz         Chill (Surf)       74
